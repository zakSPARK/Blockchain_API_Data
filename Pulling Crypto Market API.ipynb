# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


def call_API():
    global dfr
    global pd
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'10',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'c7404f41-23dc-452c-b476-df15a47c3212',
    }

    #c7404f41-23dc-452c-b476-df15a47c3212 personal CoinMarketCAP API Key


    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data_v = json.loads(response.text)
      #print(data_v)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    import pandas as pd
    # pd.set_option('display.expand_frame_repr', False)
    # pd.set_option('max_colwidth', -1)
    pd.set_option('display.max_columns', None)
    
    #Pull data into dataframe
#     dfr = pd.json_normalize(data_v['data'])
#     dfr['timestamp'] = pd.to_datetime('now', utc = True)
    
#     dfr2 = pd.json_normalize(data_v['data'])
#     dfr2['timestamp'] = pd.to_datetime('now', utc = True)
    
#     dfr = dfr.append(dfr2)
    
    #Pull data into CSV file
    
    dfr = pd.json_normalize(data_v['data'])
#     dfr['timestamp'] = pd.to_datetime('now', utc = True)
    dfr['timestamp'] = pd.to_datetime('now')
    
    if not os.path.isfile(r'C:\Users\Akinwalesz\Downloads\Personal\PythonAutomationAPIpullrequest\APICryptoData.csv'):
        dfr.to_csv(r'C:\Users\Akinwalesz\Downloads\Personal\PythonAutomationAPIpullrequest\APICryptoData.csv', header = 'column_names')
    else:
        dfr.to_csv(r'C:\Users\Akinwalesz\Downloads\Personal\PythonAutomationAPIpullrequest\APICryptoData.csv', mode = 'a', header =False)

# %%
import os
from time import time
from time import sleep

for i in range(300):
    call_API()
    print('API called successfully')
    sleep(90) #pause API call every 90 seconds
exit()
# Out:
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# C:\Users\Akinwalesz\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# API called successfully
# HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=10&convert=USD (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000145840152E0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed'))
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [49], in <cell line: 5>()
#       3 from time import sleep
#       5 for i in range(300):
# ----> 6     call_API()
#       7     print('API called successfully')
#       8     sleep(90) #pause API call every 90 seconds
#
# Input In [48], in call_API()
#      37     pd.set_option('display.max_columns', None)
#      39     #Pull data into dataframe
#      40 #     dfr = pd.json_normalize(data_v['data'])
#      41 #     dfr['timestamp'] = pd.to_datetime('now', utc = True)
#    (...)
#      47
#      48     #Pull data into CSV file
# ---> 50     dfr = pd.json_normalize(data_v['data'])
#      51 #     dfr['timestamp'] = pd.to_datetime('now', utc = True)
#      52     dfr['timestamp'] = pd.to_datetime('now')
#
# UnboundLocalError: local variable 'data_v' referenced before assignment

# %%
# pd.set_option('display.max_columns', None)
dfrcsv = pd.read_csv(r'C:\Users\Akinwalesz\Downloads\Personal\PythonAutomationAPIpullrequest\APICryptoData.csv')
dfrcsv
# Out:
#     Unnamed: 0    id         name symbol         slug  num_market_pairs  \
# 0            0     1      Bitcoin    BTC      bitcoin              9534
# 1            1  1027     Ethereum    ETH     ethereum              5751
# 2            2   825       Tether   USDT       tether             34812
# 3            3  3408     USD Coin   USDC     usd-coin              4473
# 4            4  1839          BNB    BNB          bnb               960
# ..         ...   ...          ...    ...          ...               ...
# 75           5  4687  Binance USD   BUSD  binance-usd              3852
# 76           6  2010      Cardano    ADA      cardano               459
# 77           7    52          XRP    XRP          xrp               739
# 78           8  5426       Solana    SOL       solana               334
# 79           9    74     Dogecoin   DOGE     dogecoin               486
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# ..                       ...
# 75  2019-09-20T00:00:00.000Z
# 76  2017-10-01T00:00:00.000Z
# 77  2013-08-04T00:00:00.000Z
# 78  2020-04-10T00:00:00.000Z
# 79  2013-12-15T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 1   ['mineable', 'pow', 'smart-contracts', 'ethere...                NaN
# 2   ['payments', 'stablecoin', 'asset-backed-stabl...                NaN
# 3   ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 4   ['marketplace', 'centralized-exchange', 'payme...    165116760.00000
# ..                                                ...                ...
# 75  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 76  ['mineable', 'dpos', 'pos', 'platform', 'resea...  45000000000.00000
# 77  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 78  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 79  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
#
#     circulating_supply       total_supply  platform  cmc_rank  \
# 0       19070450.00000     19070450.00000       NaN         1
# 1      121216217.93650    121216217.93650       NaN         2
# 2    68230995596.95109  79710622658.18631       NaN         3
# 3    55258671212.87383  55258671212.87383       NaN         4
# 4      163276974.63000    163276974.63000       NaN         5
# ..                 ...                ...       ...       ...
# 75   17587788126.29926  17587788126.29926       NaN         6
# 76   33752565071.28800  34512850428.99300       NaN         7
# 77   48343101197.00000  99989535142.00000       NaN         8
# 78     342379642.95611    511616946.14229       NaN         9
# 79  132670764299.89407 132670764299.89407       NaN        10
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# ..                               ...                       ...        ...
# 75                               NaN                       NaN        NaN
# 76                               NaN                       NaN        NaN
# 77                               NaN                       NaN        NaN
# 78                               NaN                       NaN        NaN
# 79                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2022-06-18T11:51:00.000Z      19338.78952     33083204113.65521
# 1   2022-06-18T11:50:00.000Z       1008.56074     15467353680.58969
# 2   2022-06-18T11:50:00.000Z          0.99880     50111100277.74266
# 3   2022-06-18T11:50:00.000Z          1.00030      5489409699.45824
# 4   2022-06-18T11:50:00.000Z        203.68234      1247226856.52071
# ..                       ...              ...                   ...
# 75  2022-06-18T11:59:00.000Z          0.99925      5456642466.92465
# 76  2022-06-18T11:59:00.000Z          0.46712       922722630.79303
# 77  2022-06-18T12:00:00.000Z          0.30639      1223728934.14968
# 78  2022-06-18T11:59:00.000Z         30.02392      1366379563.48715
# 79  2022-06-18T12:00:00.000Z          0.05424       471839819.45309
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       1.07060                     -0.12290
# 1                     -16.96560                      0.18447
# 2                      -5.76190                      0.00497
# 3                      -7.84850                     -0.01061
# 4                      -8.59020                     -0.09598
# ..                          ...                          ...
# 75                     -1.36030                     -0.22723
# 76                    -14.50360                     -0.91028
# 77                    -23.61360                     -0.82991
# 78                    -22.28760                      1.20581
# 79                    -27.66460                     -0.91634
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -8.33865                    -32.72405
# 1                       -8.49082                    -36.08845
# 2                       -0.01453                     -0.03614
# 3                        0.00916                      0.04323
# 4                       -6.89433                    -27.11682
# ..                           ...                          ...
# 75                      -0.21618                     -0.19220
# 76                      -4.98774                    -19.28955
# 77                      -5.87777                    -18.50620
# 78                      -5.07320                    -15.02257
# 79                      -5.57073                    -25.36975
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -34.18337                     -52.60270
# 1                      -48.40009                     -66.93609
# 2                       -0.02385                      -0.14891
# 3                        0.01062                       0.02009
# 4                      -32.11561                     -51.58302
# ..                           ...                           ...
# 75                      -0.25591                      -0.08047
# 76                     -11.75950                     -49.98920
# 77                     -25.02025                     -60.10025
# 78                     -41.12927                     -70.79810
# 79                     -36.14216                     -61.28201
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -53.64658    368799418666.30872
# 1                      -65.33120    122253918295.84444
# 2                       -0.17217     68148833968.05569
# 3                        0.04080     55275015015.12238
# 4                      -48.35743     33256635517.07529
# ..                           ...                   ...
# 75                       0.00307     17574598301.76241
# 76                     -47.29926     15766520128.24818
# 77                     -62.07460     14811995114.79437
# 78                     -66.66310     10279578848.33450
# 79                     -55.01443      7196515513.05763
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         43.43930                  406114579991.15997
# 1                         14.36700                  122253918295.84000
# 2                          8.00870                   79614637621.75999
# 3                          6.50510                   55275015015.12000
# 4                          3.91380                   33631367297.95000
# ..                             ...                                 ...
# 75                         2.07220                   17574598301.76000
# 76                         1.85960                   21020429240.64000
# 77                         1.74650                   30639315120.55000
# 78                         1.21210                   15360746020.43000
# 79                         0.84980                    7196515513.06000
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0             NaN  2022-06-18T11:51:00.000Z          NaN           NaN
# 1             NaN  2022-06-18T11:50:00.000Z          NaN           NaN
# 2             NaN  2022-06-18T11:50:00.000Z   1027.00000      Ethereum
# 3             NaN  2022-06-18T11:50:00.000Z   1027.00000      Ethereum
# 4             NaN  2022-06-18T11:50:00.000Z          NaN           NaN
# ..            ...                       ...          ...           ...
# 75            NaN  2022-06-18T11:59:00.000Z   1839.00000           BNB
# 76            NaN  2022-06-18T11:59:00.000Z          NaN           NaN
# 77            NaN  2022-06-18T12:00:00.000Z          NaN           NaN
# 78            NaN  2022-06-18T11:59:00.000Z          NaN           NaN
# 79            NaN  2022-06-18T12:00:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN           NaN                                         NaN
# ..             ...           ...                                         ...
# 75             BNB           bnb                                    BUSD-BD1
# 76             NaN           NaN                                         NaN
# 77             NaN           NaN                                         NaN
# 78             NaN           NaN                                         NaN
# 79             NaN           NaN                                         NaN
#
#                      timestamp
# 0   2022-06-18 11:54:07.417063
# 1   2022-06-18 11:54:07.417063
# 2   2022-06-18 11:54:07.417063
# 3   2022-06-18 11:54:07.417063
# 4   2022-06-18 11:54:07.417063
# ..                         ...
# 75  2022-06-18 12:04:44.531600
# 76  2022-06-18 12:04:44.531600
# 77  2022-06-18 12:04:44.531600
# 78  2022-06-18 12:04:44.531600
# 79  2022-06-18 12:04:44.531600
#
# [80 rows x 37 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
dfrcsv1 = dfrcsv.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
dfcsvstack = dfrcsv1.stack()
# dfrcsv1
dfcsvstack
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.40346
#              quote.USD.percent_change_24h    -8.21100
#              quote.USD.percent_change_7d    -32.77338
#              quote.USD.percent_change_30d   -34.39284
#              quote.USD.percent_change_60d   -52.65933
#              quote.USD.percent_change_90d   -53.69753
# Ethereum     quote.USD.percent_change_1h     -0.03115
#              quote.USD.percent_change_24h    -8.28954
#              quote.USD.percent_change_7d    -36.08869
#              quote.USD.percent_change_30d   -48.57382
#              quote.USD.percent_change_60d   -66.97926
#              quote.USD.percent_change_90d   -65.31576
# Tether       quote.USD.percent_change_1h     -0.00459
#              quote.USD.percent_change_24h    -0.02115
#              quote.USD.percent_change_7d     -0.04982
#              quote.USD.percent_change_30d    -0.02223
#              quote.USD.percent_change_60d    -0.14897
#              quote.USD.percent_change_90d    -0.18065
# USD Coin     quote.USD.percent_change_1h     -0.02750
#              quote.USD.percent_change_24h     0.00359
#              quote.USD.percent_change_7d      0.01220
#              quote.USD.percent_change_30d    -0.03610
#              quote.USD.percent_change_60d     0.02041
#              quote.USD.percent_change_90d     0.04703
# BNB          quote.USD.percent_change_1h     -0.30821
#              quote.USD.percent_change_24h    -6.69540
#              quote.USD.percent_change_7d    -27.09484
#              quote.USD.percent_change_30d   -32.40309
#              quote.USD.percent_change_60d   -51.61534
#              quote.USD.percent_change_90d   -48.39133
# Binance USD  quote.USD.percent_change_1h     -0.09560
#              quote.USD.percent_change_24h    -0.02637
#              quote.USD.percent_change_7d     -0.02551
#              quote.USD.percent_change_30d    -0.09744
#              quote.USD.percent_change_60d    -0.01360
#              quote.USD.percent_change_90d     0.00133
# Cardano      quote.USD.percent_change_1h     -0.67066
#              quote.USD.percent_change_24h    -5.02882
#              quote.USD.percent_change_7d    -19.31976
#              quote.USD.percent_change_30d   -10.78191
#              quote.USD.percent_change_60d   -49.94651
#              quote.USD.percent_change_90d   -47.31213
# XRP          quote.USD.percent_change_1h     -0.68750
#              quote.USD.percent_change_24h    -5.86778
#              quote.USD.percent_change_7d    -18.48214
#              quote.USD.percent_change_30d   -24.71774
#              quote.USD.percent_change_60d   -60.09821
#              quote.USD.percent_change_90d   -62.08526
# Solana       quote.USD.percent_change_1h      1.45934
#              quote.USD.percent_change_24h    -5.01712
#              quote.USD.percent_change_7d    -15.03450
#              quote.USD.percent_change_30d   -40.54529
#              quote.USD.percent_change_60d   -70.77525
#              quote.USD.percent_change_90d   -66.66137
# Dogecoin     quote.USD.percent_change_1h     -0.75193
#              quote.USD.percent_change_24h    -5.61978
#              quote.USD.percent_change_7d    -25.43147
#              quote.USD.percent_change_30d   -35.94549
#              quote.USD.percent_change_60d   -61.31506
#              quote.USD.percent_change_90d   -55.06044
# dtype: float64

# %%
# type(dfrcsv1) ---------> pandas.core.frame.DataFrame
# type(dfcsvstack) --------> pandas.core.series.Series

# Convert dfcsvstack to dataframe
dfcsvstack1 = dfcsvstack.to_frame(name= 'Values')
# type(dfcsvstack1) ------> pandas.core.frame.DataFrame
dfcsvstack1
# Out:
#                                             Values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.40346
#             quote.USD.percent_change_24h  -8.21100
#             quote.USD.percent_change_7d  -32.77338
#             quote.USD.percent_change_30d -34.39284
#             quote.USD.percent_change_60d -52.65933
#             quote.USD.percent_change_90d -53.69753
# Ethereum    quote.USD.percent_change_1h   -0.03115
#             quote.USD.percent_change_24h  -8.28954
#             quote.USD.percent_change_7d  -36.08869
#             quote.USD.percent_change_30d -48.57382
#             quote.USD.percent_change_60d -66.97926
#             quote.USD.percent_change_90d -65.31576
# Tether      quote.USD.percent_change_1h   -0.00459
#             quote.USD.percent_change_24h  -0.02115
#             quote.USD.percent_change_7d   -0.04982
#             quote.USD.percent_change_30d  -0.02223
#             quote.USD.percent_change_60d  -0.14897
#             quote.USD.percent_change_90d  -0.18065
# USD Coin    quote.USD.percent_change_1h   -0.02750
#             quote.USD.percent_change_24h   0.00359
#             quote.USD.percent_change_7d    0.01220
#             quote.USD.percent_change_30d  -0.03610
#             quote.USD.percent_change_60d   0.02041
#             quote.USD.percent_change_90d   0.04703
# BNB         quote.USD.percent_change_1h   -0.30821
#             quote.USD.percent_change_24h  -6.69540
#             quote.USD.percent_change_7d  -27.09484
#             quote.USD.percent_change_30d -32.40309
#             quote.USD.percent_change_60d -51.61534
#             quote.USD.percent_change_90d -48.39133
# Binance USD quote.USD.percent_change_1h   -0.09560
#             quote.USD.percent_change_24h  -0.02637
#             quote.USD.percent_change_7d   -0.02551
#             quote.USD.percent_change_30d  -0.09744
#             quote.USD.percent_change_60d  -0.01360
#             quote.USD.percent_change_90d   0.00133
# Cardano     quote.USD.percent_change_1h   -0.67066
#             quote.USD.percent_change_24h  -5.02882
#             quote.USD.percent_change_7d  -19.31976
#             quote.USD.percent_change_30d -10.78191
#             quote.USD.percent_change_60d -49.94651
#             quote.USD.percent_change_90d -47.31213
# XRP         quote.USD.percent_change_1h   -0.68750
#             quote.USD.percent_change_24h  -5.86778
#             quote.USD.percent_change_7d  -18.48214
#             quote.USD.percent_change_30d -24.71774
#             quote.USD.percent_change_60d -60.09821
#             quote.USD.percent_change_90d -62.08526
# Solana      quote.USD.percent_change_1h    1.45934
#             quote.USD.percent_change_24h  -5.01712
#             quote.USD.percent_change_7d  -15.03450
#             quote.USD.percent_change_30d -40.54529
#             quote.USD.percent_change_60d -70.77525
#             quote.USD.percent_change_90d -66.66137
# Dogecoin    quote.USD.percent_change_1h   -0.75193
#             quote.USD.percent_change_24h  -5.61978
#             quote.USD.percent_change_7d  -25.43147
#             quote.USD.percent_change_30d -35.94549
#             quote.USD.percent_change_60d -61.31506
#             quote.USD.percent_change_90d -55.06044

# %%
# dfcsvstack1.count() ---------> 60
# index our stacked dataframe
index = pd.Index(range(60))
dfcsvstack2 = dfcsvstack1.set_index(index)
dfcsvstack2 = dfcsvstack1.reset_index()

dfcsvstack2
# Out:
#            name                       level_1    Values
# 0       Bitcoin   quote.USD.percent_change_1h   1.19491
# 1       Bitcoin  quote.USD.percent_change_24h  -8.05624
# 2       Bitcoin   quote.USD.percent_change_7d -33.80192
# 3       Bitcoin  quote.USD.percent_change_30d -33.67727
# 4       Bitcoin  quote.USD.percent_change_60d -52.66317
# 5       Bitcoin  quote.USD.percent_change_90d -53.83003
# 6      Ethereum   quote.USD.percent_change_1h   0.82222
# 7      Ethereum  quote.USD.percent_change_24h  -8.56816
# 8      Ethereum   quote.USD.percent_change_7d -37.61066
# 9      Ethereum  quote.USD.percent_change_30d -48.24227
# 10     Ethereum  quote.USD.percent_change_60d -67.14345
# 11     Ethereum  quote.USD.percent_change_90d -65.71273
# 12       Tether   quote.USD.percent_change_1h  -0.00028
# 13       Tether  quote.USD.percent_change_24h  -0.00820
# 14       Tether   quote.USD.percent_change_7d  -0.04849
# 15       Tether  quote.USD.percent_change_30d  -0.00650
# 16       Tether  quote.USD.percent_change_60d  -0.14833
# 17       Tether  quote.USD.percent_change_90d  -0.17977
# 18     USD Coin   quote.USD.percent_change_1h   0.01489
# 19     USD Coin  quote.USD.percent_change_24h   0.02903
# 20     USD Coin   quote.USD.percent_change_7d   0.04105
# 21     USD Coin  quote.USD.percent_change_30d   0.02592
# 22     USD Coin  quote.USD.percent_change_60d   0.06846
# 23     USD Coin  quote.USD.percent_change_90d   0.06739
# 24          BNB   quote.USD.percent_change_1h   1.66591
# 25          BNB  quote.USD.percent_change_24h  -6.80811
# 26          BNB   quote.USD.percent_change_7d -28.72554
# 27          BNB  quote.USD.percent_change_30d -31.40001
# 28          BNB  quote.USD.percent_change_60d -51.63411
# 29          BNB  quote.USD.percent_change_90d -48.52102
# 30  Binance USD   quote.USD.percent_change_1h   0.07132
# 31  Binance USD  quote.USD.percent_change_24h   0.02997
# 32  Binance USD   quote.USD.percent_change_7d   0.13230
# 33  Binance USD  quote.USD.percent_change_30d  -0.04411
# 34  Binance USD  quote.USD.percent_change_60d   0.18150
# 35  Binance USD  quote.USD.percent_change_90d   0.15317
# 36      Cardano   quote.USD.percent_change_1h   2.15668
# 37      Cardano  quote.USD.percent_change_24h  -4.39908
# 38      Cardano   quote.USD.percent_change_7d -21.83849
# 39      Cardano  quote.USD.percent_change_30d  -8.45774
# 40      Cardano  quote.USD.percent_change_60d -49.67969
# 41      Cardano  quote.USD.percent_change_90d -47.55985
# 42          XRP   quote.USD.percent_change_1h   1.13969
# 43          XRP  quote.USD.percent_change_24h  -6.29604
# 44          XRP   quote.USD.percent_change_7d -19.73581
# 45          XRP  quote.USD.percent_change_30d -23.68126
# 46          XRP  quote.USD.percent_change_60d -60.04029
# 47          XRP  quote.USD.percent_change_90d -62.05837
# 48       Solana   quote.USD.percent_change_1h   1.40487
# 49       Solana  quote.USD.percent_change_24h  -7.00338
# 50       Solana   quote.USD.percent_change_7d -21.36470
# 51       Solana  quote.USD.percent_change_30d -40.93459
# 52       Solana  quote.USD.percent_change_60d -71.49375
# 53       Solana  quote.USD.percent_change_90d -67.87823
# 54     Dogecoin   quote.USD.percent_change_1h   1.66328
# 55     Dogecoin  quote.USD.percent_change_24h  -6.37321
# 56     Dogecoin   quote.USD.percent_change_7d -29.15661
# 57     Dogecoin  quote.USD.percent_change_30d -36.04947
# 58     Dogecoin  quote.USD.percent_change_60d -61.78232
# 59     Dogecoin  quote.USD.percent_change_90d -55.95691

# %%
dfcsvstack3 = dfcsvstack2.rename(columns = {'level_1' : '%_Change'})
dfcsvstack3['%_Change'] = dfcsvstack3['%_Change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'], ['1hr', '24hrs', '7days', '30days', '60days', '90days'])

dfcsvstack3
# Out:
#            name %_Change    Values
# 0       Bitcoin      1hr   1.19491
# 1       Bitcoin    24hrs  -8.05624
# 2       Bitcoin    7days -33.80192
# 3       Bitcoin   30days -33.67727
# 4       Bitcoin   60days -52.66317
# 5       Bitcoin   90days -53.83003
# 6      Ethereum      1hr   0.82222
# 7      Ethereum    24hrs  -8.56816
# 8      Ethereum    7days -37.61066
# 9      Ethereum   30days -48.24227
# 10     Ethereum   60days -67.14345
# 11     Ethereum   90days -65.71273
# 12       Tether      1hr  -0.00028
# 13       Tether    24hrs  -0.00820
# 14       Tether    7days  -0.04849
# 15       Tether   30days  -0.00650
# 16       Tether   60days  -0.14833
# 17       Tether   90days  -0.17977
# 18     USD Coin      1hr   0.01489
# 19     USD Coin    24hrs   0.02903
# 20     USD Coin    7days   0.04105
# 21     USD Coin   30days   0.02592
# 22     USD Coin   60days   0.06846
# 23     USD Coin   90days   0.06739
# 24          BNB      1hr   1.66591
# 25          BNB    24hrs  -6.80811
# 26          BNB    7days -28.72554
# 27          BNB   30days -31.40001
# 28          BNB   60days -51.63411
# 29          BNB   90days -48.52102
# 30  Binance USD      1hr   0.07132
# 31  Binance USD    24hrs   0.02997
# 32  Binance USD    7days   0.13230
# 33  Binance USD   30days  -0.04411
# 34  Binance USD   60days   0.18150
# 35  Binance USD   90days   0.15317
# 36      Cardano      1hr   2.15668
# 37      Cardano    24hrs  -4.39908
# 38      Cardano    7days -21.83849
# 39      Cardano   30days  -8.45774
# 40      Cardano   60days -49.67969
# 41      Cardano   90days -47.55985
# 42          XRP      1hr   1.13969
# 43          XRP    24hrs  -6.29604
# 44          XRP    7days -19.73581
# 45          XRP   30days -23.68126
# 46          XRP   60days -60.04029
# 47          XRP   90days -62.05837
# 48       Solana      1hr   1.40487
# 49       Solana    24hrs  -7.00338
# 50       Solana    7days -21.36470
# 51       Solana   30days -40.93459
# 52       Solana   60days -71.49375
# 53       Solana   90days -67.87823
# 54     Dogecoin      1hr   1.66328
# 55     Dogecoin    24hrs  -6.37321
# 56     Dogecoin    7days -29.15661
# 57     Dogecoin   30days -36.04947
# 58     Dogecoin   60days -61.78232
# 59     Dogecoin   90days -55.95691

# %%
import seaborn as sbn
import matplotlib.pyplot as mplt

sbn.catplot(x='%_Change', y='Values', hue='name', data=dfcsvstack3, kind='point')

# %%
dfrsolana = dfrcsv[['name', 'quote.USD.price', 'timestamp']]
dfrsolana = dfrsolana.query("name == 'Solana'")
dfrsolana
# Out:
#       name  quote.USD.price                   timestamp
# 8   Solana         30.15497  2022-06-18 11:54:07.417063
# 18  Solana         30.15497  2022-06-18 11:55:38.461546
# 28  Solana         30.07823  2022-06-18 11:57:09.452454
# 38  Solana         30.07823  2022-06-18 11:58:40.418229
# 48  Solana         30.07823  2022-06-18 12:00:11.547889
# 58  Solana         30.02392  2022-06-18 12:01:42.650237
# 68  Solana         30.02392  2022-06-18 12:03:13.703144
# 78  Solana         30.02392  2022-06-18 12:04:44.531600

# %%
sbn.set_theme(style= 'darkgrid')

sbn.lineplot(x='timestamp', y='quote.USD.price', data=dfrsolana)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='quote.USD.price'>
